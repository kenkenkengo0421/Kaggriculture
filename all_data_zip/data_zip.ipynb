# %%
# !unzip -qo /content/test.zip -d /data
# !unzip -qo /content/st_data.zip -d /data

# %% [markdown]
# ```
#
# test.ipynb
#         |__test.zip
#         |__st_data.zip
#         |__kaggriculture_df.py   https://github.com/kenkenkengo0421/Kaggriculture/blob/main/Kaggriculture_Movements_in_the_top_xx%25/kaggriculture_df.py
#
#
# ```

# %%
from kaggriculture_df import Kaggriculture_df
import pandas as pd


#1
df_data1_01_00 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank10_score52465.0_p1.json", 0)).df
df_data1_01_01 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank10_score52465.0_p1.json", 1)).df
df_data1_02_00 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank11_score52627.0_p1.json", 0)).df
df_data1_02_01 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank11_score52627.0_p1.json", 1)).df
df_data1_03_00 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank12_score52731.0_p1.json", 0)).df
df_data1_03_01 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank12_score52731.0_p1.json", 1)).df
df_data1_04_00 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank13_score52935.0_p1.json", 0)).df
df_data1_04_01 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank13_score52935.0_p1.json", 1)).df
df_data1_05_00 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank14_score52963.0_p1.json", 0)).df
df_data1_05_01 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank14_score52963.0_p1.json", 1)).df
df_data1_06_00 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank15_score52971.0_p0.json", 0)).df
df_data1_06_01 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank15_score52971.0_p0.json", 1)).df
df_data1_07_00 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank1_score51526.0_p0.json", 0)).df
df_data1_07_01 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank1_score51526.0_p0.json", 1)).df
df_data1_08_00 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank2_score51544.0_p1.json", 0)).df
df_data1_08_01 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank2_score51544.0_p1.json", 1)).df
df_data1_09_00 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank3_score52009.0_p1.json", 0)).df
df_data1_09_01 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank3_score52009.0_p1.json", 1)).df
df_data1_10_00 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank4_score52031.0_p1.json", 0)).df
df_data1_10_01 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank4_score52031.0_p1.json", 1)).df
df_data1_11_00 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank5_score52091.0_p1.json", 0)).df
df_data1_11_01 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank5_score52091.0_p1.json", 1)).df
df_data1_12_00 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank6_score52121.0_p0.json", 0)).df
df_data1_12_01 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank6_score52121.0_p0.json", 1)).df
df_data1_13_00 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank7_score52161.0_p0.json", 0)).df
df_data1_13_01 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank7_score52161.0_p0.json", 1)).df
df_data1_14_00 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank8_score52221.0_p1.json", 0)).df
df_data1_14_01 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank8_score52221.0_p1.json", 1)).df
df_data1_15_00 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank9_score52348.0_p0.json", 0)).df
df_data1_15_01 = (Kaggriculture_df("/data/test/be_data_0_1/beginner_rank9_score52348.0_p0.json", 1)).df


#2
df_data2_01_00 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank10_score62296.0_p1.json", 0)).df
df_data2_01_01 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank10_score62296.0_p1.json", 1)).df
df_data2_02_00 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank11_score62305.0_p1.json", 0)).df
df_data2_02_01 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank11_score62305.0_p1.json", 1)).df
df_data2_03_00 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank12_score62323.0_p1.json", 0)).df
df_data2_03_01 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank12_score62323.0_p1.json", 1)).df
df_data2_04_00 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank13_score62346.0_p1.json", 0)).df
df_data2_04_01 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank13_score62346.0_p1.json", 1)).df
df_data2_05_00 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank14_score62412.0_p0.json", 0)).df
df_data2_05_01 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank14_score62412.0_p0.json", 1)).df
df_data2_06_00 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank15_score62440.0_p0.json", 0)).df
df_data2_06_01 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank15_score62440.0_p0.json", 1)).df
df_data2_07_00 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank1_score61637.0_p0.json", 0)).df
df_data2_07_01 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank1_score61637.0_p0.json", 1)).df
df_data2_08_00 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank2_score61656.0_p0.json", 0)).df
df_data2_08_01 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank2_score61656.0_p0.json", 1)).df
df_data2_09_00 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank3_score61679.0_p1.json", 0)).df
df_data2_09_01 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank3_score61679.0_p1.json", 1)).df
df_data2_10_00 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank4_score61699.0_p0.json", 0)).df
df_data2_10_01 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank4_score61699.0_p0.json", 1)).df
df_data2_11_00 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank5_score61711.0_p1.json", 0)).df
df_data2_11_01 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank5_score61711.0_p1.json", 1)).df
df_data2_12_00 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank6_score61723.0_p1.json", 0)).df
df_data2_12_01 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank6_score61723.0_p1.json", 1)).df
df_data2_13_00 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank7_score61891.0_p0.json", 0)).df
df_data2_13_01 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank7_score61891.0_p0.json", 1)).df
df_data2_14_00 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank8_score62048.0_p1.json", 0)).df
df_data2_14_01 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank8_score62048.0_p1.json", 1)).df
df_data2_15_00 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank9_score62249.0_p1.json", 0)).df
df_data2_15_01 = (Kaggriculture_df("/data/test/be_data_0_2/beginner_rank9_score62249.0_p1.json", 1)).df


#3
df_data3_01_00 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank10_score69412.0_p0.json", 0)).df
df_data3_01_01 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank10_score69412.0_p0.json", 1)).df
df_data3_02_00 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank11_score69595.0_p1.json", 0)).df
df_data3_02_01 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank11_score69595.0_p1.json", 1)).df
df_data3_03_00 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank12_score69646.0_p0.json", 0)).df
df_data3_03_01 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank12_score69646.0_p0.json", 1)).df
df_data3_04_00 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank13_score69675.0_p1.json", 0)).df
df_data3_04_01 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank13_score69675.0_p1.json", 1)).df
df_data3_05_00 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank14_score69685.0_p1.json", 0)).df
df_data3_05_01 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank14_score69685.0_p1.json", 1)).df
df_data3_06_00 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank15_score69719.0_p1.json", 0)).df
df_data3_06_01 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank15_score69719.0_p1.json", 1)).df
df_data3_07_00 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank1_score69094.0_p1.json", 0)).df
df_data3_07_01 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank1_score69094.0_p1.json", 1)).df
df_data3_08_00 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank2_score69112.0_p1.json", 0)).df
df_data3_08_01 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank2_score69112.0_p1.json", 1)).df
df_data3_09_00 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank3_score69156.0_p1.json", 0)).df
df_data3_09_01 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank3_score69156.0_p1.json", 1)).df
df_data3_10_00 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank4_score69203.0_p0.json", 0)).df
df_data3_10_01 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank4_score69203.0_p0.json", 1)).df
df_data3_11_00 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank5_score69216.0_p0.json", 0)).df
df_data3_11_01 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank5_score69216.0_p0.json", 1)).df
df_data3_12_00 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank6_score69254.0_p0.json", 0)).df
df_data3_12_01 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank6_score69254.0_p0.json", 1)).df
df_data3_13_00 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank7_score69266.0_p1.json", 0)).df
df_data3_13_01 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank7_score69266.0_p1.json", 1)).df
df_data3_14_00 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank8_score69272.0_p0.json", 0)).df
df_data3_14_01 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank8_score69272.0_p0.json", 1)).df
df_data3_15_00 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank9_score69295.0_p0.json", 0)).df
df_data3_15_01 = (Kaggriculture_df("/data/test/be_data_0_3/beginner_rank9_score69295.0_p0.json", 1)).df


#4
df_data4_01_00 = (Kaggriculture_df("/data/test/be_data_0_4/beginner_rank10_score75904.0_p0.json", 0)).df
df_data4_01_01 = (Kaggriculture_df("/data/test/be_data_0_4/beginner_rank10_score75904.0_p0.json", 1)).df
df_data4_02_00 = (Kaggriculture_df("/data/test/be_data_0_4/beginner_rank11_score75934.0_p1.json", 0)).df
df_data4_02_01 = (Kaggriculture_df("/data/test/be_data_0_4/beginner_rank11_score75934.0_p1.json", 1)).df
df_data4_03_00 = (Kaggriculture_df("/data/test/be_data_0_4/beginner_rank12_score75943.0_p0.json", 0)).df
df_data4_03_01 = (Kaggriculture_df("/data/test/be_data_0_4/beginner_rank12_score75943.0_p0.json", 1)).df
df_data4_04_00 = (Kaggriculture_df("/data/test/be_data_0_4/beginner_rank13_score75949.0_p0.json", 0)).df
df_data4_04_01 = (Kaggriculture_df("/data/test/be_data_0_4/beginner_rank13_score75949.0_p0.json", 1)).df
df_data4_05_00 = (Kaggriculture_df("/data/test/be_data_0_4/beginner_r
00 = (Kaggriculture_df("/data/test/be_data_0_7/beginner_rank8_score99971.0_p0.json", 0)).df
df_data7_13_01 = (Kaggriculture_df("/data/test/be_data_0_7/beginner_rank8_score99971.0_p0.json", 1)).df
df_data7_14_00 = (Kaggriculture_df("/data/test/be_data_0_7/beginner_rank9_score100057.0_p0.json", 0)).df
df_data7_14_01 = (Kaggriculture_df("/data/test/be_data_0_7/beginner_rank9_score100057.0_p0.json", 1)).df
df_data7_15_00 = (Kaggriculture_df("/data/test/be_data_0_7/beginner_rank13_score100176.0_p1.json", 0)).df
df_data7_15_01 = (Kaggriculture_df("/data/test/be_data_0_7/beginner_rank13_score100176.0_p1.json", 1)).df


#8
df_data8_01_00 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank10_score109836.0_p0.json", 0)).df
df_data8_01_01 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank10_score109836.0_p0.json", 1)).df
df_data8_02_00 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank11_score110009.0_p1.json", 0)).df
df_data8_02_01 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank11_score110009.0_p1.json", 1)).df
df_data8_03_00 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank12_score110167.0_p1.json", 0)).df
df_data8_03_01 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank12_score110167.0_p1.json", 1)).df
df_data8_04_00 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank13_score110209.0_p1.json", 0)).df
df_data8_04_01 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank13_score110209.0_p1.json", 1)).df
df_data8_05_00 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank14_score110314.0_p0.json", 0)).df
df_data8_05_01 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank14_score110314.0_p0.json", 1)).df
df_data8_06_00 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank15_score110405.0_p1.json", 0)).df
df_data8_06_01 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank15_score110405.0_p1.json", 1)).df
df_data8_07_00 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank1_score109335.0_p1.json", 0)).df
df_data8_07_01 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank1_score109335.0_p1.json", 1)).df
df_data8_08_00 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank2_score109404.0_p0.json", 0)).df
df_data8_08_01 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank2_score109404.0_p0.json", 1)).df
df_data8_09_00 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank3_score109442.0_p1.json", 0)).df
df_data8_09_01 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank3_score109442.0_p1.json", 1)).df
df_data8_10_00 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank4_score109470.0_p0.json", 0)).df
df_data8_10_01 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank4_score109470.0_p0.json", 1)).df
df_data8_11_00 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank5_score109486.0_p0.json", 0)).df
df_data8_11_01 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank5_score109486.0_p0.json", 1)).df
df_data8_12_00 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank6_score109580.0_p0.json", 0)).df
df_data8_12_01 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank6_score109580.0_p0.json", 1)).df
df_data8_13_00 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank7_score109728.0_p1.json", 0)).df
df_data8_13_01 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank7_score109728.0_p1.json", 1)).df
df_data8_14_00 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank8_score109731.0_p0.json", 0)).df
df_data8_14_01 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank8_score109731.0_p0.json", 1)).df
df_data8_15_00 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank9_score109830.0_p0.json", 0)).df
df_data8_15_01 = (Kaggriculture_df("/data/test/be_data_0_8/beginner_rank9_score109830.0_p0.json", 1)).df


#9
df_data9_01_00 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank10_score122874.0_p0.json", 0)).df
df_data9_01_01 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank10_score122874.0_p0.json", 1)).df
df_data9_02_00 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank11_score123770.0_p0.json", 0)).df
df_data9_02_01 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank11_score123770.0_p0.json", 1)).df
df_data9_03_00 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank12_score123770.0_p1.json", 0)).df
df_data9_03_01 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank12_score123770.0_p1.json", 1)).df
df_data9_04_00 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank13_score123932.0_p1.json", 0)).df
df_data9_04_01 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank13_score123932.0_p1.json", 1)).df
df_data9_05_00 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank14_score124194.0_p1.json", 0)).df
df_data9_05_01 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank14_score124194.0_p1.json", 1)).df
df_data9_06_00 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank15_score124218.0_p0.json", 0)).df
df_data9_06_01 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank15_score124218.0_p0.json", 1)).df
df_data9_07_00 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank1_score121795.0_p1.json", 0)).df
df_data9_07_01 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank1_score121795.0_p1.json", 1)).df
df_data9_08_00 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank2_score121864.0_p1.json", 0)).df
df_data9_08_01 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank2_score121864.0_p1.json", 1)).df
df_data9_09_00 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank3_score121886.0_p1.json", 0)).df
df_data9_09_01 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank3_score121886.0_p1.json", 1)).df
df_data9_10_00 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank4_score122015.0_p0.json", 0)).df
df_data9_10_01 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank4_score122015.0_p0.json", 1)).df
df_data9_11_00 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank5_score122200.0_p1.json", 0)).df
df_data9_11_01 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank5_score122200.0_p1.json", 1)).df
df_data9_12_00 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank6_score122269.0_p0.json", 0)).df
df_data9_12_01 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank6_score122269.0_p0.json", 1)).df
df_data9_13_00 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank7_score122617.0_p0.json", 0)).df
df_data9_13_01 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank7_score122617.0_p0.json", 1)).df
df_data9_14_00 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank8_score122655.0_p0.json", 0)).df
df_data9_14_01 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank8_score122655.0_p0.json", 1)).df
df_data9_15_00 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank9_score122672.0_p0.json", 0)).df
df_data9_15_01 = (Kaggriculture_df("/data/test/be_data_0_9/beginner_rank9_score122672.0_p0.json", 1)).df

#st
df_data_st_01_00 = (Kaggriculture_df("/data/st_data/strong_rank10_score144477.0_p1.json", 0)).df
df_data_st_01_01 = (Kaggriculture_df("/data/st_data/strong_rank10_score144477.0_p1.json", 1)).df
df_data_st_02_00 = (Kaggriculture_df("/data/st_data/strong_rank11_score144322.0_p0.json", 0)).df
df_data_st_02_01 = (Kaggriculture_df("/data/st_data/strong_rank11_score144322.0_p0.json", 1)).df
df_data_st_03_00 = (Kaggriculture_df("/data/st_data/strong_rank12_score144221.0_p1.json", 0)).df
df_data_st_03_01 = (Kaggriculture_df("/data/st_data/strong_rank12_score144221.0_p1.json", 1)).df
df_data_st_04_00 = (Kaggriculture_df("/data/st_data/strong_rank13_score143927.0_p0.json", 0)).df
df_data_st_04_01 = (Kaggriculture_df("/data/st_data/strong_rank13_score143927.0_p0.json", 1)).df
df_data_st_05_00 = (Kaggriculture_df("/data/st_data/strong_rank14_score143742.0_p1.json", 0)).df
df_data_st_05_01 = (Kaggriculture_df("/data/st_data/strong_rank14_score143742.0_p1.json", 1)).df
df_data_st_06_00 = (Kaggriculture_df("/data/st_data/strong_rank1_score157577.0_p1.json", 0)).df
df_data_st_06_01 = (Kaggriculture_df("/data/st_data/strong_rank1_score157577.0_p1.json", 1)).df
df_data_st_07_00 = (Kaggriculture_df("/data/st_data/strong_rank2_score157005.0_p0.json", 0)).df
df_data_st_07_01 = (Kaggriculture_df("/data/st_data/strong_rank2_score157005.0_p0.json", 1)).df
df_data_st_08_00 = (Kaggriculture_df("/data/st_data/strong_rank3_score150533.0_p1.json", 0)).df
df_data_st_08_01 = (Kaggriculture_df("/data/st_data/strong_rank3_score150533.0_p1.json", 1)).df
df_data_st_09_00 = (Kaggriculture_df("/data/st_data/strong_rank4_score149240.0_p0.json", 0)).df
df_data_st_09_01 = (Kaggriculture_df("/data/st_data/strong_rank4_score149240.0_p0.json", 1)).df
df_data_st_10_00 = (Kaggriculture_df("/data/st_data/strong_rank5_score148193.0_p1.json", 0)).df
df_data_st_10_01 = (Kaggriculture_df("/data/st_data/strong_rank5_score148193.0_p1.json", 1)).df
df_data_st_11_00 = (Kaggriculture_df("/data/st_data/strong_rank6_score146250.0_p1.json", 0)).df
df_data_st_11_01 = (Kaggriculture_df("/data/st_data/strong_rank6_score146250.0_p1.json", 1)).df
df_data_st_12_00 = (Kaggriculture_df("/data/st_data/strong_rank7_score145329.0_p0.json", 0)).df
df_data_st_12_01 = (Kaggriculture_df("/data/st_data/strong_rank7_score145329.0_p0.json", 1)).df
df_data_st_13_00 = (Kaggriculture_df("/data/st_data/strong_rank8_score145177.0_p1.json", 0)).df
df_data_st_13_01 = (Kaggriculture_df("/data/st_data/strong_rank8_score145177.0_p1.json", 1)).df
df_data_st_14_00 = (Kaggriculture_df("/data/st_data/strong_rank9_score145111.0_p0.json", 0)).df
df_data_st_14_01 = (Kaggriculture_df("/data/st_data/strong_rank9_score145111.0_p0.json", 1)).df

# %%
df_data_1 = pd.concat([
    df_data1_01_00,
    df_data1_01_01,
    df_data1_02_00,
    df_data1_02_01,
    df_data1_03_00,
    df_data1_03_01,
    df_data1_04_00,
    df_data1_04_01,
    df_data1_05_00,
    df_data1_05_01,
    df_data1_06_00,
    df_data1_06_01,
    df_data1_07_00,
    df_data1_07_01,
    df_data1_08_00,
    df_data1_08_01,
    df_data1_09_00,
    df_data1_09_01,
    df_data1_10_00,
    df_data1_10_01,
    df_data1_11_00,
    df_data1_11_01,
    df_data1_12_00,
    df_data1_12_01,
    df_data1_13_00,
    df_data1_13_01,
    df_data1_14_00,
    df_data1_14_01,
    df_data1_15_00,
    df_data1_15_01,
], ignore_index=True)

df_data_1["id"] = 1


df_data_2 = pd.concat([
    df_data2_01_00,
    df_data2_01_01,
    df_data2_02_00,
    df_data2_02_01,
    df_data2_03_00,
    df_data2_03_01,
    df_data2_04_00,
    df_data2_04_01,
    df_data2_05_00,
    df_data2_05_01,
    df_data2_06_00,
    df_data2_06_01,
    df_data2_07_00,
    df_data2_07_01,
    df_data2_08_00,
    df_data2_08_01,
    df_data2_09_00,
    df_data2_09_01,
    df_data2_10_00,
    df_data2_10_01,
    df_data2_11_00,
    df_data2_11_01,
    df_data2_12_00,
    df_data2_12_01,
    df_data2_13_00,
    df_data2_13_01,
    df_data2_14_00,
    df_data2_14_01,
    df_data2_15_00,
    df_data2_15_01,
], ignore_index=True)

df_data_2["id"] = 2


df_data_3 = pd.concat([
    df_data3_01_00,
    df_data3_01_01,
    df_data3_02_00,
    df_data3_02_01,
    df_data3_03_00,
    df_data3_03_01,
    df_data3_04_00,
    df_data3_04_01,
    df_data3_05_00,
    df_data3_05_01,
    df_data3_06_00,
    df_data3_06_01,
    df_data3_07_00,
    df_data3_07_01,
    df_data3_08_00,
    df_data3_08_01,
    df_data3_09_00,
    df_data3_09_01,
    df_data3_10_00,
    df_data3_10_01,
    df_data3_11_00,
    df_data3_11_01,
    df_data3_12_00,
    df_data3_12_01,
    df_data3_13_00,
    df_data3_13_01,
    df_data3_14_00,
    df_data3_14_01,
    df_data3_15_00,
    df_data3_15_01,
], ignore_index=True)

df_data_3["id"] = 3


df_data_4 = pd.concat([
    df_data4_01_00,
    df_data4_01_01,
    df_data4_02_00,
    df_data4_02_01,
    df_data4_03_00,
    df_data4_03_01,
    df_data4_04_00,
    df_data4_04_01,
    df_data4_05_00,
    df_data4_05_01,
    df_data4_06_00,
    df_data4_06_01,
    df_data4_07_00,
    df_data4_07_01,
    df_data4_08_00,
    df_data4_08_01,
    df_data4_09_00,
    df_data4_09_01,
    df_data4_10_00,
    df_data4_10_01,
    df_data4_11_00,
    df_data4_11_01,
    df_data4_12_00,
    df_data4_12_01,
    df_data4_13_00,
    df_data4_13_01,
    df_data4_14_00,
    df_data4_14_01,
    df_data4_15_00,
    df_data4_15_01,
], ignore_index=True)

df_data_4["id"] = 4


df_data_5 = pd.concat([
    df_data5_01_00,
    df_data5_01_01,
    df_data5_02_00,
    df_data5_02_01,
    df_data5_03_00,
    df_data5_03_01,
    df_data5_04_00,
    df_data5_04_01,
    df_data5_05_00,
    df_data5_05_01,
    df_data5_06_00,
    df_data5_06_01,
    df_data5_07_00,
    df_data5_07_01,
    df_data5_08_00,
    df_data5_08_01,
    df_data5_09_00,
    df_data5_09_01,
    df_data5_10_00,
    df_data5_10_01,
    df_data5_11_00,
    df_data5_11_01,
    df_data5_12_00,
    df_data5_12_01,
    df_data5_13_00,
    df_data5_13_01,
    df_data5_14_00,
    df_data5_14_01,
    df_data5_15_00,
    df_data5_15_01,
], ignore_index=True)

df_data_5["id"] = 5


df_data_6 = pd.concat([
    df_data6_01_00,
    df_data6_01_01,
    df_data6_02_00,
    df_data6_02_01,
    df_data6_03_00,
    df_data6_03_01,
    df_data6_04_00,
    df_data6_04_01,
    df_data6_05_00,
    df_data6_05_01,
    df_data6_06_00,
    df_data6_06_01,
    df_data6_07_00,
    df_data6_07_01,
    df_data6_08_00,
    df_data6_08_01,
    df_data6_09_00,
    df_data6_09_01,
    df_data6_10_00,
    df_data6_10_01,
    df_data6_11_00,
    df_data6_11_01,
    df_data6_12_00,
    df_data6_12_01,
    df_data6_13_00,
    df_data6_13_01,
    df_data6_14_00,
    df_data6_14_01,
    df_data6_15_00,
    df_data6_15_01,
], ignore_index=True)

df_data_6["id"] = 6


df_data_7 = pd.concat([
    df_data7_01_00,
    df_data7_01_01,
    df_data7_02_00,
    df_data7_02_01,
    df_data7_03_00,
    df_data7_03_01,
    df_data7_04_00,
    df_data7_04_01,
    df_data7_05_00,
    df_data7_05_01,
    df_data7_06_00,
    df_data7_06_01,
    df_data7_07_00,
    df_data7_07_01,
    df_data7_08_00,
    df_data7_08_01,
    df_data7_09_00,
    df_data7_09_01,
    df_data7_10_00,
    df_data7_10_01,
    df_data7_11_00,
    df_data7_11_01,
    df_data7_12_00,
    df_data7_12_01,
    df_data7_13_00,
    df_data7_13_01,
    df_data7_14_00,
    df_data7_14_01,
    df_data7_15_00,
    df_data7_15_01,
], ignore_index=True)

df_data_7["id"] = 7


df_data_8 = pd.concat([
    df_data8_01_00,
    df_data8_01_01,
    df_data8_02_00,
    df_data8_02_01,
    df_data8_03_00,
    df_data8_03_01,
    df_data8_04_00,
    df_data8_04_01,
    df_data8_05_00,
    df_data8_05_01,
    df_data8_06_00,
    df_data8_06_01,
    df_data8_07_00,
    df_data8_07_01,
    df_data8_08_00,
    df_data8_08_01,
    df_data8_09_00,
    df_data8_09_01,
    df_data8_10_00,
    df_data8_10_01,
    df_data8_11_00,
    df_data8_11_01,
    df_data8_12_00,
    df_data8_12_01,
    df_data8_13_00,
    df_data8_13_01,
    df_data8_14_00,
    df_data8_14_01,
    df_data8_15_00,
    df_data8_15_01,
], ignore_index=True)

df_data_8["id"] = 8


df_data_9 = pd.concat([
    df_data9_01_00,
    df_data9_01_01,
    df_data9_02_00,
    df_data9_02_01,
    df_data9_03_00,
    df_data9_03_01,
    df_data9_04_00,
    df_data9_04_01,
    df_data9_05_00,
    df_data9_05_01,
    df_data9_06_00,
    df_data9_06_01,
    df_data9_07_00,
    df_data9_07_01,
    df_data9_08_00,
    df_data9_08_01,
    df_data9_09_00,
    df_data9_09_01,
    df_data9_10_00,
    df_data9_10_01,
    df_data9_11_00,
    df_data9_11_01,
    df_data9_12_00,
    df_data9_12_01,
    df_data9_13_00,
    df_data9_13_01,
    df_data9_14_00,
    df_data9_14_01,
    df_data9_15_00,
    df_data9_15_01,
], ignore_index=True)

df_data_9["id"] = 9


df_data_st = pd.concat([
    df_data_st_01_00,
    df_data_st_01_01,
    df_data_st_02_00,
    df_data_st_02_01,
    df_data_st_03_00,
    df_data_st_03_01,
    df_data_st_04_00,
    df_data_st_04_01,
    df_data_st_05_00,
    df_data_st_05_01,
    df_data_st_06_00,
    df_data_st_06_01,
    df_data_st_07_00,
    df_data_st_07_01,
    df_data_st_08_00,
    df_data_st_08_01,
    df_data_st_09_00,
    df_data_st_09_01,
    df_data_st_10_00,
    df_data_st_10_01,
    df_data_st_11_00,
    df_data_st_11_01,
    df_data_st_12_00,
    df_data_st_12_01,
    df_data_st_13_00,
    df_data_st_13_01,
    df_data_st_14_00,
    df_data_st_14_01,
], ignore_index=True)

df_data_st["id"] = 10

# %%
df_all_data_final = pd.concat([
    df_data_1,
    df_data_2,
    df_data_3,
    df_data_4,
    df_data_5,
    df_data_6,
    df_data_7,
    df_data_8,
    df_data_9,
    df_data_st,
])

# %%
df_all_data_final
# Out:
#        step  day     money                                              tiles  \
# 0         0    0    3000.0  [[None, None, None, None, None, LOCKED, LOCKED...
# 1         1    0      22.0  [[None, None, None, None, None, LOCKED, LOCKED...
# 2         2    0      50.0  [[None, None, None, None, None, LOCKED, LOCKED...
# 3         3    0      22.0  [[None, None, None, None, None, LOCKED, LOCKED...
# 4         4    0      50.0  [[None, None, None, None, None, LOCKED, LOCKED...
# ...     ...  ...       ...                                                ...
# 20155   715   29  133491.0  [[None, None, None, None, None, None, {'consec...
# 20156   716   29  135784.0  [[None, None, None, None, None, None, {'consec...
# 20157   717   29  144863.0  [[None, None, None, None, None, None, {'consec...
# 20158   718   29  145818.0  [[None, None, None, None, None, None, {'consec...
# 20159   719   29  146250.0  [[None, None, None, None, None, None, {'consec...
#
# ...

# %%
df_all_data_final.to_csv("df_all_data_final.csv", index=False)

# %%
# !zip df_all_data_final.zip df_all_data_final.csv
# Out:
#   adding: df_all_data_final.csv (deflated 98%)
